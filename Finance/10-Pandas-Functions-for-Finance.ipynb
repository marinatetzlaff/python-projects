# %% [markdown]
# # 10 Pandas Functions for Finance

# %% [markdown]
# Data source: https://www.kaggle.com/dgawlik/nyse

# %%
import numpy as np
import pandas as pd

# %%
from IPython.display import display, Markdown

# %%
df = pd.read_csv("fundamentals.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0           0           AAL    2012-12-31      3.068000e+09
# 1           1           AAL    2013-12-31      4.975000e+09
# 2           2           AAL    2014-12-31      4.668000e+09
# 3           3           AAL    2015-12-31      5.102000e+09
# 4           4           AAP    2012-12-29      2.409453e+09
#
#    Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0         -222000000.0               -1.961000e+09           23.0
# 1          -93000000.0               -2.723000e+09           67.0
# 2         -160000000.0               -1.500000e+08          143.0
# 3          352000000.0               -7.080000e+08          135.0
# 4          -89482000.0                6.000000e+05           32.0
#
#    Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 0         -1.888000e+09     4.695000e+09        53.0  ...
# 1         -3.114000e+09     1.059200e+10        75.0  ...
# ...

# %% [markdown]
# # 1. Cumsum

# %% [markdown]
# ### Cumulative Sum  of Total Revenue

# %%
df['Cumsum of Total Revenue'] = df[['Total Revenue','Ticker Symbol']].groupby('Ticker Symbol').cumsum()
df
# Out:
#       Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 0              0           AAL    2012-12-31      3.068000e+09
# 1              1           AAL    2013-12-31      4.975000e+09
# 2              2           AAL    2014-12-31      4.668000e+09
# 3              3           AAL    2015-12-31      5.102000e+09
# 4              4           AAP    2012-12-29      2.409453e+09
# ...          ...           ...           ...               ...
# 1776        1776          ZION    2015-12-31      0.000000e+00
# 1777        1777           ZTS    2013-12-31      1.381000e+09
# 1778        1778           ZTS    2014-12-31      1.071000e+09
# 1779        1779           ZTS    2015-12-31      1.313000e+09
# 1780        1780           ZTS    2016-12-31      1.076000e+09
#
#       Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 0            -222000000.0               -1.961000e+09           23.0
# ...

# %%
display(Markdown(
f"""Positive Equity Figures"""
))
# Out:
# Positive Equity Figures

# %% [markdown]
# # 2. Where

# %% [markdown]
# ### Where Total Equity is positive

# %%
df['Total Equity'].where(df['Total Equity'] > 0 , 0)
# Out:
# 0       0.000000e+00
# 1       0.000000e+00
# 2       2.021000e+09
# 3       5.635000e+09
# 4       1.210694e+09
#             ...
# 1776    7.507519e+09
# 1777    9.400000e+08
# 1778    1.311000e+09
# 1779    1.068000e+09
# 1780    1.487000e+09
# Name: Total Equity, Length: 1781, dtype: float64

# %% [markdown]
# # 3. Is In

# %% [markdown]
# ### Where data is in maximum year

# %%
df['For Year'].max()
# Out:
# 2016.0

# %%
df[df['For Year'].isin(['2016'])]
# Out:
#       Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 11            11          AAPL    2016-09-24      5.932100e+10
# 19            19           ABC    2016-09-30      2.467016e+10
# 31            31           ADI    2016-10-29      4.313960e+08
# 43            43          ADSK    2016-01-31      5.221000e+08
# 99            99          AMAT    2016-10-30      2.056000e+09
# ...          ...           ...           ...               ...
# 1677        1677           WDC    2016-07-01      3.615000e+09
# 1689        1689           WFM    2016-09-25      7.570000e+08
# 1709        1709           WMT    2016-01-31      5.861500e+10
# 1712        1712           WRK    2016-09-30      1.460300e+09
# 1744        1744          XLNX    2016-04-02      3.072220e+08
#
#       Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 11           1.044000e+09                1.348000e+09           36.0
# ...

# %% [markdown]
# # 4. ILoc

# %%
df.iloc[:2,:3]
# Out:
#    Unnamed: 0 Ticker Symbol Period Ending
# 0           0           AAL    2012-12-31
# 1           1           AAL    2013-12-31

# %%
df.loc[:2, ['Accounts Payable','Accounts Receivable']]
# Out:
#    Accounts Payable  Accounts Receivable
# 0      3.068000e+09         -222000000.0
# 1      4.975000e+09          -93000000.0
# 2      4.668000e+09         -160000000.0

# %%
df_aapl = df[df['Ticker Symbol'] == 'AAPL']
df_aapl
# Out:
#     Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 8            8          AAPL    2013-09-28      3.622300e+10
# 9            9          AAPL    2014-09-27      4.864900e+10
# 10          10          AAPL    2015-09-26      6.067100e+10
# 11          11          AAPL    2016-09-24      5.932100e+10
#
#     Accounts Receivable  Add'l income/expense items  After Tax ROE  \
# 8         -1.949000e+09                1.156000e+09           30.0
# 9         -6.452000e+09                9.800000e+08           35.0
# 10        -3.124000e+09                1.285000e+09           45.0
# 11         1.044000e+09                1.348000e+09           36.0
#
#     Capital Expenditures  Capital Surplus  Cash Ratio  ...  \
# 8          -8.165000e+09              0.0        93.0  ...
# 9          -9.571000e+09              0.0        40.0  ...
# 10         -1.124700e+10              0.0        52.0  ...
# 11         -1.273400e+10              0.0        85.0  ...
#
# ...

# %% [markdown]
# # 5. Pct_change

# %%
df_aapl['Total Equity'].pct_change()
# Out:
# 8          NaN
# 9    -0.097144
# 10    0.069997
# 11    0.074517
# Name: Total Equity, dtype: float64

# %%
df_2016 = df[df['For Year'].isin(['2016'])]

# %% [markdown]
# # 6. Rank

# %%
df_2016['CR_rank'] = df_2016['Cash Ratio'].rank()
df_2016
# Out:
# <ipython-input-15-42171cd0c9d1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2016['CR_rank'] = df_2016['Cash Ratio'].rank()
#       Unnamed: 0 Ticker Symbol Period Ending  Accounts Payable  \
# 11            11          AAPL    2016-09-24      5.932100e+10
# 19            19           ABC    2016-09-30      2.467016e+10
# 31            31           ADI    2016-10-29      4.313960e+08
# 43            43          ADSK    2016-01-31      5.221000e+08
# 99            99          AMAT    2016-10-30      2.056000e+09
# ...          ...           ...           ...               ...
# 1677        1677           WDC    2016-07-01      3.615000e+09
# 1689        1689           WFM    2016-09-25      7.570000e+08
# ...

# %% [markdown]
# # 7. Melt

# %%
accounts_cols = [col for col in df.columns if 'Accounts' in col]
print(accounts_cols)
# Out:
# ['Accounts Payable', 'Accounts Receivable']

# %%
df_wide = df.loc[:, ['Ticker Symbol','Accounts Payable','Accounts Receivable']]

# %%
df_wide
# Out:
#      Ticker Symbol  Accounts Payable  Accounts Receivable
# 0              AAL      3.068000e+09         -222000000.0
# 1              AAL      4.975000e+09          -93000000.0
# 2              AAL      4.668000e+09         -160000000.0
# 3              AAL      5.102000e+09          352000000.0
# 4              AAP      2.409453e+09          -89482000.0
# ...            ...               ...                  ...
# 1776          ZION      0.000000e+00                  0.0
# 1777           ZTS      1.381000e+09          -99000000.0
# 1778           ZTS      1.071000e+09           69000000.0
# 1779           ZTS      1.313000e+09          -58000000.0
# 1780           ZTS      1.076000e+09           15000000.0
#
# [1781 rows x 3 columns]

# %%
df_wide.melt(id_vars=['Ticker Symbol'])
# Out:
#      Ticker Symbol             variable         value
# 0              AAL     Accounts Payable  3.068000e+09
# 1              AAL     Accounts Payable  4.975000e+09
# 2              AAL     Accounts Payable  4.668000e+09
# 3              AAL     Accounts Payable  5.102000e+09
# 4              AAP     Accounts Payable  2.409453e+09
# ...            ...                  ...           ...
# 3557          ZION  Accounts Receivable  0.000000e+00
# 3558           ZTS  Accounts Receivable -9.900000e+07
# 3559           ZTS  Accounts Receivable  6.900000e+07
# 3560           ZTS  Accounts Receivable -5.800000e+07
# 3561           ZTS  Accounts Receivable  1.500000e+07
#
# [3562 rows x 3 columns]

# %% [markdown]
# # 8. Nunique

# %%
df['For Year'].nunique()
# Out:
# 6

# %% [markdown]
# # 9. Memory_usage

# %%
df.memory_usage().sum() / (1024**2) #converting to megabytes
# Out:
# 1.087158203125

# %% [markdown]
# # 10. Describe

# %%
df.describe()
# Out:
#         Unnamed: 0  Accounts Payable  Accounts Receivable  \
# count  1781.000000      1.781000e+03         1.781000e+03
# mean    890.000000      4.673418e+09        -6.353484e+07
# std     514.274732      1.406047e+10         7.562794e+08
# min       0.000000      0.000000e+00        -6.452000e+09
# 25%     445.000000      5.160000e+08        -1.040000e+08
# 50%     890.000000      1.334000e+09        -1.830000e+07
# 75%    1335.000000      3.246000e+09         7.816000e+06
# max    1780.000000      2.069390e+11         2.266400e+10
#
#        Add'l income/expense items  After Tax ROE  Capital Expenditures  \
# count                1.781000e+03    1781.000000          1.781000e+03
# mean                 6.908940e+07      43.601348         -1.251925e+09
# std                  6.848143e+08     233.924028          2.979963e+09
# min                 -6.768000e+09       0.000000         -3.798500e+10
# 25%                 -2.638000e+06      10.000000         -1.151200e+09
# ...
